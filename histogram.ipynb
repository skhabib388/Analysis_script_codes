# %%
import pandas as pd, matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from colors import colors
from matplotlib.path import Path
import matplotlib.patches as patches
import math
mpl.rc('figure')

mpl.rcParams['text.usetex'] = True
mpl.rcParams[
    'text.latex.preamble'] = r'\usepackage[cm]{sfmath}\usepackage{amsmath}\usepackage{amssymb}'

mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = 'CMU Sans Serif'

font_size = 25

fonts = {
    "axes.labelsize": font_size,
    "font.size": font_size,
    "legend.fontsize": font_size,
    "xtick.labelsize": font_size,
    "ytick.labelsize": font_size,
    "axes.titlesize": font_size,
}

mpl.rcParams.update(fonts)

axes_settings = {
    "axes.labelcolor": '#2e2e2e',
    "axes.spines.top": True,
    "axes.spines.right": True,
    "xtick.direction": "out",
    "ytick.direction": "out",
    "xtick.color": '#2e2e2e',
    "ytick.color": '#2e2e2e',
    "text.color": '#2e2e2e',
    "axes.edgecolor": '#2e2e2e',
}
mpl.rcParams.update(axes_settings)



df=pd.read_csv("Mg_l4_tetraloop_low_K_conc/fold_2_unfold/Rg_0-6195ns_RMSD_0.1",sep='\s+',comment="#")
df1=pd.read_csv("Mg_l4_tetraloop_low_K_conc/fold_2_unfold/Rg_0-6195ns_RMSD_0.25",sep='\s+',comment="#")
df2=pd.read_csv("Mg_l4_tetraloop_low_K_conc/fold_2_unfold/Rg_0-6195ns_RMSD_0.4",sep='\s+',comment="#")
df3=pd.read_csv("Mg_l4_tetraloop_low_K_conc/fold_2_unfold/Rg_0-6195ns_RMSD_0.68",sep='\s+',comment="#")
fig,ax= plt.subplots(figsize=(8,6),dpi=800,constrained_layout=True)
t,r=df.iloc[:,0],df.iloc[:,1]
t1,r1=df1.iloc[:,0],df1.iloc[:,1]
t2,r2=df2.iloc[:,0],df2.iloc[:,1]
t3,r3=df3.iloc[:,0],df3.iloc[:,1]

# plt.hist(r,bins=100,facecolor="blue",density=True,label="F",edgecolor = "orange", fill=True)

ax.hist(r, bins=200, histtype='step', linewidth=1.5, facecolor="peachpuff", 
         edgecolor='saddlebrown',fill=True, density=True,label="F", alpha=0.8,)
ax.hist(r1,bins=200, histtype='step', linewidth=1.5, facecolor='violet', 
        edgecolor='purple',fill=True, density=True,label="PF1",alpha=0.7)
ax.hist(r2,bins=200, histtype='step', linewidth=1.5, facecolor='greenyellow', 
        edgecolor='darkgreen',fill=True, density=True,label="PF2",alpha=0.5)
ax.hist(r3,bins=200, histtype='step', linewidth=1.5, facecolor='aqua', 
        edgecolor='darkcyan',fill=True, density=True,label="U",alpha=0.4)
plt.legend()
ax.set_xlim([0.70,1.0])
ax.set_yticks(np.arange(5, 55, 15))
# ax.set_xticks(np.arange(0.7, 1.0, 0.05))
ax.set_xlabel("Radius of Gyration, R$_g$ (nm)")
ax.set_ylabel("Frequency")
plt.savefig("Mg_l4_tetraloop_low_K_conc/fold_2_unfold/Rg_distribution_Mg.pdf", format="pdf", bbox_inches='tight', dpi=1200)

# %%
import pandas as pd, matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from colors import colors
from matplotlib.path import Path
import matplotlib.patches as patches
import math
mpl.rc('figure')

mpl.rcParams['text.usetex'] = True
mpl.rcParams[
    'text.latex.preamble'] = r'\usepackage[cm]{sfmath}\usepackage{amsmath}\usepackage{amssymb}'

mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = 'CMU Sans Serif'

font_size = 25

fonts = {
    "axes.labelsize": font_size,
    "font.size": font_size,
    "legend.fontsize": font_size,
    "xtick.labelsize": font_size,
    "ytick.labelsize": font_size,
    "axes.titlesize": font_size,
}

mpl.rcParams.update(fonts)

axes_settings = {
    "axes.labelcolor": '#2e2e2e',
    "axes.spines.top": True,
    "axes.spines.right": True,
    "xtick.direction": "out",
    "ytick.direction": "out",
    "xtick.color": '#2e2e2e',
    "ytick.color": '#2e2e2e',
    "text.color": '#2e2e2e',
    "axes.edgecolor": '#2e2e2e',
}
mpl.rcParams.update(axes_settings)



df=pd.read_csv("Ca_l4_tetraloop_low_K_conc/Rg_0-4025ns_RMSD_0.1.dat",sep='\s+',comment="#")
df1=pd.read_csv("Ca_l4_tetraloop_low_K_conc/Rg_0-4025ns_RMSD_0.25.dat",sep='\s+',comment="#")
df2=pd.read_csv("Ca_l4_tetraloop_low_K_conc/Rg_0-4025ns_RMSD_0.4.dat",sep='\s+',comment="#")
df3=pd.read_csv("Ca_l4_tetraloop_low_K_conc/Rg_0-4025ns_RMSD_0.66.dat",sep='\s+',comment="#")
fig,ax= plt.subplots(figsize=(8,6),dpi=800,constrained_layout=True)
t,r=df.iloc[:,0],df.iloc[:,1]
t1,r1=df1.iloc[:,0],df1.iloc[:,1]
t2,r2=df2.iloc[:,0],df2.iloc[:,1]
t3,r3=df3.iloc[:,0],df3.iloc[:,1]

# plt.hist(r,bins=100,facecolor="blue",density=True,label="F",edgecolor = "orange", fill=True)

ax.hist(r, bins=200, histtype='step', linewidth=1.5, facecolor="peachpuff", 
         edgecolor='saddlebrown',fill=True, density=True,label="F", alpha=0.8,)
ax.hist(r1,bins=200, histtype='step', linewidth=1.5, facecolor='violet', 
        edgecolor='purple',fill=True, density=True,label="PF1",alpha=0.7)
ax.hist(r2,bins=200, histtype='step', linewidth=1.5, facecolor='greenyellow', 
        edgecolor='darkgreen',fill=True, density=True,label="PF2",alpha=0.5)
ax.hist(r3,bins=200, histtype='step', linewidth=1.5, facecolor='aqua', 
        edgecolor='darkcyan',fill=True, density=True,label="U",alpha=0.4)

plt.legend()
ax.set_xlim([0.70,1.0])
ax.set_yticks(np.arange(5, 55, 15))
ax.set_xticks(np.arange(0.7, 1.0, 0.5))
ax.set_xlabel("Radius of Gyration, R$_g$ (nm)")
ax.set_ylabel("Frequency")
plt.savefig("Ca_l4_tetraloop_low_K_conc/Rg_distribution_Ca.pdf", format="pdf", bbox_inches='tight', dpi=1200)

# %%
import pandas as pd, matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from colors import colors
from matplotlib.path import Path
import matplotlib.patches as patches
import math
mpl.rc('figure')

mpl.rcParams['text.usetex'] = True
mpl.rcParams[
    'text.latex.preamble'] = r'\usepackage[cm]{sfmath}\usepackage{amsmath}\usepackage{amssymb}'

mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = 'CMU Sans Serif'

font_size = 25

fonts = {
    "axes.labelsize": font_size,
    "font.size": font_size,
    "legend.fontsize": font_size,
    "xtick.labelsize": font_size,
    "ytick.labelsize": font_size,
    "axes.titlesize": font_size,
}

mpl.rcParams.update(fonts)

axes_settings = {
    "axes.labelcolor": '#2e2e2e',
    "axes.spines.top": True,
    "axes.spines.right": True,
    "xtick.direction": "out",
    "ytick.direction": "out",
    "xtick.color": '#2e2e2e',
    "ytick.color": '#2e2e2e',
    "text.color": '#2e2e2e',
    "axes.edgecolor": '#2e2e2e',
}
mpl.rcParams.update(axes_settings)



df=pd.read_csv("Ca_l4_tetraloop_low_K_conc/Rg_0-4025ns_RMSD_0.1.dat",sep='\s+',comment="#")
df1=pd.read_csv("Ca_l4_tetraloop_low_K_conc/Rg_0-4025ns_RMSD_0.25.dat",sep='\s+',comment="#")
df2=pd.read_csv("Ca_l4_tetraloop_low_K_conc/Rg_0-4025ns_RMSD_0.4.dat",sep='\s+',comment="#")
df3=pd.read_csv("Ca_l4_tetraloop_low_K_conc/Rg_0-4025ns_RMSD_0.66.dat",sep='\s+',comment="#")
fig,ax= plt.subplots(figsize=(8,6),dpi=800,constrained_layout=True)
t,r=df.iloc[:,0],df.iloc[:,1]
t1,r1=df1.iloc[:,0],df1.iloc[:,1]
t2,r2=df2.iloc[:,0],df2.iloc[:,1]
t3,r3=df3.iloc[:,0],df3.iloc[:,1]

# plt.hist(r,bins=100,facecolor="blue",density=True,label="F",edgecolor = "orange", fill=True)

ax.hist(r, bins=200, histtype='step', linewidth=1.5,fill=True, density=True,label="F", alpha=0.3)
ax.hist(r1,bins=200, histtype='step', linewidth=1.5,fill=True, density=True,label="PF1",alpha=0.3)
ax.hist(r2,bins=200, histtype='step', linewidth=1.5,fill=True, density=True,label="PF2",alpha=0.3)
ax.hist(r3,bins=200, histtype='step', linewidth=1.5,fill=True, density=True,label="U",alpha=0.3)
plt.legend()
ax.set_xlim([0.70,1.0])
ax.set_yticks(np.arange(5, 55, 15))
ax.set_xticks(np.arange(0.7, 1.0, 0.5))
ax.set_xlabel("Radius of Gyration, R$_g$ (nm)")
ax.set_ylabel("Frequency")
plt.savefig("Ca_l4_tetraloop_low_K_conc/Rg_distribution_Ca.pdf", format="pdf", bbox_inches='tight', dpi=1200)
