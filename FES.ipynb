# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from colors import colors
from matplotlib.path import Path
import matplotlib.patches as patches

df=pd.read_csv("../L4_tetraloop_project/Ca_l4_tetraloop_low_K_conc/CN_d/fes.dat",sep='\s+',comment="#")

fig, ax = plt.subplots(1,1,figsize=(6,4),dpi=800,constrained_layout=True)
# fig=plt.figure(figsize=(6,4))
eRMSD,d,G=df.iloc[:,0],df.iloc[:,1],df.iloc[:,2]

#th=input("Enter the value of Gth\n")
#th=float(th)
th=-30
#cscheme=input("Enter the color scheme\n")
cscheme="nipy_spectral"
# gmax=input("Enter the maximum value of G\n")
gmax=58
i=np.where(G<=th)
j=np.where(G==np.min(G))
m=G[j[0][0]]
print(f"min:{m} at i={j}")
G=G[i[0]] - m
d=d[i[0]]
gmin=min(G)
gmax=int(gmax)#max(G)/2
eRMSD=eRMSD[i[0]]
#z=np.cos(eRMSD*eRMSD)*np.cos(d*eRMSD)

a=np.shape(eRMSD)
b=np.shape(d)
c=np.shape(G)
print(a)
print(b)
print(c)
t=ax.tricontourf(eRMSD,d,G,levels=50,cmap=cscheme,vmax=gmax,vmin=gmin)
mpl.rc('figure')

mpl.rcParams['text.usetex'] = True
mpl.rcParams[
    'text.latex.preamble'] = r'\usepackage[cm]{sfmath}\usepackage{amsmath}\usepackage{amssymb}'

mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = 'CMU Sans Serif'

font_size = 20

fonts = {
    "axes.labelsize": font_size,
    "font.size": font_size,
    "legend.fontsize": font_size,
    "xtick.labelsize": font_size,
    "ytick.labelsize": font_size,
    "axes.titlesize": font_size,
}

mpl.rcParams.update(fonts)

axes_settings = {
    "axes.labelcolor": '#2e2e2e',
    "axes.spines.top": True,
    "axes.spines.right": True,
    "xtick.direction": "out",
    "ytick.direction": "out",
    "xtick.color": '#2e2e2e',
    "ytick.color": '#2e2e2e',
    "text.color": '#2e2e2e',
    "axes.edgecolor": '#2e2e2e',
}
mpl.rcParams.update(axes_settings)
cbar = fig.colorbar(t,ticks=[0,14,28,42,56])
cbar.set_label(label=r"$G$ (kJ/mol)")
plt.xticks(np.arange(0.2, max(eRMSD), 0.1))
plt.xlabel("d (nm)")
plt.ylabel("CN")
plt.ylim([2,10])
plt.xlim([0.2,0.7])
plt.savefig("../L4_tetraloop_project/Ca_l4_tetraloop_low_K_conc/CN_d/Fig_for_papers/FES_CN_d_2.5ns_Ca.pdf",format="pdf",bbox_inches='tight',dpi=800)
plt.show()
# Out:
# min:-87.250178142 at i=(array([6980]),)
# (6646,)
# (6646,)
# (6646,)

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from colors import colors
from matplotlib.path import Path
import matplotlib.patches as patches

df=pd.read_csv("../L4_tetraloop_project/Ca_l4_tetraloop_low_K_conc/CN_d/fes.dat",sep='\s+',comment="#")
df2=pd.read_csv("../L4_tetraloop_project/Ca_l4_tetraloop_low_K_conc/CN_eRMSD/fes.dat",sep='\s+',comment="#")
df3=pd.read_csv("../L4_tetraloop_project/Ca_l4_tetraloop_low_K_conc/d_eRMSD/fes.dat",sep='\s+',comment="#")
df4=pd.read_csv("../L4_tetraloop_project/Mg_l4_tetraloop_low_K_conc/fold_2_unfold/CN_d/fes.dat",sep='\s+',comment="#")
df5=pd.read_csv("../L4_tetraloop_project/Mg_l4_tetraloop_low_K_conc/fold_2_unfold/CN_eRMSD/fes.dat",sep='\s+',comment="#")
df6=pd.read_csv("../L4_tetraloop_project/Mg_l4_tetraloop_low_K_conc/fold_2_unfold/d_eRMSD/fes.dat",sep='\s+',comment="#")
df7=pd.read_csv("../L4_tetraloop_project/Mn_l4_tetraloop_low_K_conc/CN_d/fes.dat",sep='\s+',comment="#")
df8=pd.read_csv("../L4_tetraloop_project/Mn_l4_tetraloop_low_K_conc/CN_eRMSD/fes.dat",sep='\s+',comment="#")
df9=pd.read_csv("../L4_tetraloop_project/Mn_l4_tetraloop_low_K_conc/d_eRMSD/fes.dat",sep='\s+',comment="#")

fig, ax = plt.subplots(3,3,figsize=(8,6),dpi=800,constrained_layout=True)
# fig=plt.figure(figsize=(6,4))
eRMSD,d,G=df.iloc[:,0],df.iloc[:,1],df.iloc[:,2]
eRMSD2,d2,G2=df2.iloc[:,0],df2.iloc[:,1],df2.iloc[:,2]
eRMSD3,d3,G3=df3.iloc[:,0],df3.iloc[:,1],df3.iloc[:,2]
eRMSD4,d4,G4=df4.iloc[:,0],df4.iloc[:,1],df4.iloc[:,2]
eRMSD5,d5,G5=df5.iloc[:,0],df5.iloc[:,1],df5.iloc[:,2]
eRMSD6,d6,G6=df6.iloc[:,0],df6.iloc[:,1],df6.iloc[:,2]
eRMSD7,d7,G7=df7.iloc[:,0],df7.iloc[:,1],df7.iloc[:,2]
eRMSD8,d8,G8=df8.iloc[:,0],df8.iloc[:,1],df8.iloc[:,2]
eRMSD9,d9,G9=df9.iloc[:,0],df9.iloc[:,1],df9.iloc[:,2]



mpl.rc('figure')

mpl.rcParams['text.usetex'] = True
mpl.rcParams[
    'text.latex.preamble'] = r'\usepackage[cm]{sfmath}\usepackage{amsmath}\usepackage{amssymb}'

mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = 'CMU Sans Serif'

font_size = 5

fonts = {
    "axes.labelsize": font_size,
    "font.size": font_size,
    "legend.fontsize": font_size,
    "xtick.labelsize": font_size,
    "ytick.labelsize": font_size,
    "axes.titlesize": font_size,
}

mpl.rcParams.update(fonts)

axes_settings = {
    "axes.labelcolor": '#2e2e2e',
    "axes.spines.top": True,
    "axes.spines.right": True,
    "xtick.direction": "out",
    "ytick.direction": "out",
    "xtick.color": '#2e2e2e',
    "ytick.color": '#2e2e2e',
    "text.color": '#2e2e2e',
    "axes.edgecolor": '#2e2e2e',
}
mpl.rcParams.update(axes_settings)

#th=input("Enter the value of Gth\n")
#th=float(th)
th=-30
#cscheme=input("Enter the color scheme\n")
cscheme="nipy_spectral"
# gmax=input("Enter the maximum value of G\n")
gmax=58
i=np.where(G<=th)
j=np.where(G==np.min(G))
m=G[j[0][0]]
print(f"min:{m} at i={j}")
G=G[i[0]] - m
d=d[i[0]]
gmin=min(G)
gmax=int(gmax)#max(G)/2
eRMSD=eRMSD[i[0]]
#z=np.cos(eRMSD*eRMSD)*np.cos(d*eRMSD)

a=np.shape(eRMSD)
b=np.shape(d)
c=np.shape(G)
print(a)
print(b)
print(c)


th2=-30
#cscheme=input("Enter the color scheme\n")
cscheme="nipy_spectral"
# gmax=input("Enter the maximum value of G\n")
gmax2=58
i2=np.where(G2<=th2)
j2=np.where(G2==np.min(G2))
m2=G2[j2[0][0]]
print(f"min:{m2} at i2={j2}")
G2=G2[i2[0]] - m2
d2=d2[i2[0]]
gmin2=min(G2)
gmax2=int(gmax2)#max(G)/2
eRMSD2=eRMSD2[i2[0]]
#z=np.cos(eRMSD*eRMSD)*np.cos(d*eRMSD)

th3=-30
#cscheme=input("Enter the color scheme\n")
cscheme="nipy_spectral"
# gmax=input("Enter the maximum value of G\n")
gmax3=58
i3=np.where(G3<=th3)
j3=np.where(G3==np.min(G3))
m3=G3[j3[0][0]]
print(f"min:{m3} at i3={j3}")
G3=G3[i3[0]] - m3
d3=d3[i3[0]]
gmin3=min(G3)
gmax3=int(gmax3)#max(G)/2
eRMSD3=eRMSD3[i3[0]]
#z=np.cos(eRMSD*eRMSD)*np.cos(d*eRMSD)

th4=-20
#cscheme=input("Enter the color scheme\n")
cscheme="nipy_spectral"
# gmax=input("Enter the maximum value of G\n")
gmax4=85
i4=np.where(G4<=th4)
j4=np.where(G4==np.min(G4))
m4=G4[j4[0][0]]
print(f"min:{m4} at i4={j4}")
G4=G4[i4[0]] - m4
d4=d4[i4[0]]
gmin4=min(G4)
gmax4=int(gmax4)#max(G)/2
eRMSD4=eRMSD4[i4[0]]
#z=np.cos(eRMSD*eRMSD)*np.cos(d*eRMSD)

#th=input("Enter the value of Gth\n")
#th=float(th)
th5=-30
#cscheme=input("Enter the color scheme\n")
cscheme="nipy_spectral"
# gmax=input("Enter the maximum value of G\n")
gmax5=58
i5=np.where(G5<=th5)
j5=np.where(G5==np.min(G5))
m5=G5[j5[0][0]]
print(f"min:{m5} at i5={j5}")
G5=G5[i5[0]] - m5
d5=d5[i5[0]]
gmin5=min(G5)
gmax5=int(gmax5)#max(G)/2
eRMSD5=eRMSD5[i5[0]]
#z=np.cos(eRMSD*eRMSD)*np.cos(d*eRMSD)

a=np.shape(eRMSD)
b=np.shape(d)
c=np.shape(G)
print(a)
print(b)
print(c)


th6=-30
#cscheme=input("Enter the color scheme\n")
cscheme="nipy_spectral"
# gmax=input("Enter the maximum value of G\n")
gmax6=58
i6=np.where(G6<=th6)
j6=np.where(G6==np.min(G6))
m6=G6[j6[0][0]]
print(f"min:{m6} at i6={j6}")
G6=G6[i6[0]] - m6
d6=d6[i6[0]]
gmin6=min(G6)
gmax6=int(gmax6)#max(G)/2
eRMSD6=eRMSD6[i6[0]]
#z=np.cos(eRMSD*eRMSD)*np.cos(d*eRMSD)

th7=-30
#cscheme=input("Enter the color scheme\n")
cscheme="nipy_spectral"
# gmax=input("Enter the maximum value of G\n")
gmax7=58
i7=np.where(G7<=th7)
j7=np.where(G7==np.min(G7))
m7=G7[j7[0][0]]
print(f"min:{m7} at i7={j7}")
G7=G7[i7[0]] - m7
d7=d7[i7[0]]
gmin7=min(G7)
gmax7=int(gmax7)#max(G)/2
eRMSD7=eRMSD7[i7[0]]
#z=np.cos(eRMSD*eRMSD)*np.cos(d*eRMSD)

th8=-20
#cscheme=input("Enter the color scheme\n")
cscheme="nipy_spectral"
# gmax=input("Enter the maximum value of G\n")
gmax8=85
i8=np.where(G8<=th8)
j8=np.where(G8==np.min(G8))
m8=G8[j8[0][0]]
print(f"min:{m8} at i8={j8}")
G8=G8[i8[0]] - m8
d8=d8[i8[0]]
gmin8=min(G8)
gmax8=int(gmax8)#max(G)/2
eRMSD8=eRMSD8[i8[0]]
#z=np.cos(eRMSD*eRMSD)*np.cos(d*eRMSD)

th9=-20
#cscheme=input("Enter the color scheme\n")
cscheme="nipy_spectral"
# gmax=input("Enter the maximum value of G\n")
gmax9=85
i9=np.where(G9<=th9)
j9=np.where(G9==np.min(G9))
m9=G9[j9[0][0]]
print(f"min:{m9} at i9={j9}")
G9=G9[i9[0]] - m9
d9=d9[i9[0]]
gmin9=min(G9)
gmax9=int(gmax9)#max(G)/2
eRMSD9=eRMSD9[i9[0]]
#z=np.cos(eRMSD*eRMSD)*np.cos(d*eRMSD)

t1=ax[0,0].tricontourf(eRMSD,d,G,levels=50,cmap=cscheme)
# ax[0,0].set_xticks(np.arange(0.2, max(eRMSD1), 0.1))
ax[0,0].set_xlabel("d (nm)")
ax[0,0].set_ylabel("CN")

t2=ax[0,1].tricontourf(eRMSD2,d2,G2,levels=50,cmap=cscheme)
# ax[0,1].set_xticks(np.arange(0, max(eRMSD2), 2))
# ax[0,1].set_yticks(np.arange(2.0, max(d), 0.5))
ax[0,1].set_xlabel("CN")
ax[0,1].set_ylabel("eRMSD")

t3=ax[0,2].tricontourf(eRMSD3,d3,G3,levels=50,cmap=cscheme)
# ax[0,2].set_xticks(np.arange(0.2, max(eRMSD3), 0.1))
ax[0,2].set_xlabel("d (nm)")
ax[0,2].set_ylabel("eRMSD")

t4=ax[1,0].tricontourf(eRMSD4,d4,G4,levels=50,cmap=cscheme)
# ax[1,0].set_xticks(np.arange(0.18, max(eRMSD4), 0.1))
ax[1,0].set_xlabel("d (nm)")
ax[1,0].set_ylabel("CN")

t5=ax[1,1].tricontourf(eRMSD5,d5,G5,levels=50,cmap=cscheme)
# ax[0,2].set_xticks(np.arange(0.2, max(eRMSD3), 0.1))
ax[0,2].set_xlabel("d (nm)")
ax[0,2].set_ylabel("eRMSD")

t6=ax[1,2].tricontourf(eRMSD6,d6,G6,levels=50,cmap=cscheme)
ax[1,0].set_xlabel("d (nm)")
ax[1,0].set_ylabel("CN")

t7=ax[2,0].tricontourf(eRMSD7,d7,G7,levels=50,cmap=cscheme)
# ax[1,0].set_xticks(np.arange(0.18, max(eRMSD4), 0.1))
ax[2,0].set_xlabel("d (nm)")
ax[2,0].set_ylabel("CN")

t8=ax[2,1].tricontourf(eRMSD8,d8,G8,levels=50,cmap=cscheme)
# ax[0,2].set_xticks(np.arange(0.2, max(eRMSD3), 0.1))
ax[2,1].set_xlabel("d (nm)")
ax[2,1].set_ylabel("eRMSD")

t9=ax[2,2].tricontourf(eRMSD9,d9,G9,levels=50,cmap=cscheme)
ax[2,2].set_xlabel("d (nm)")
ax[2,2].set_ylabel("CN")



cbar1 = fig.colorbar(t1,ticks=[0,14,28,42,56])
cbar2 = fig.colorbar(t2,ticks=[0,14,28,42,56])
cbar3 = fig.colorbar(t3,ticks=[0,14,28,42,56])
cbar4 = fig.colorbar(t4,ticks=[0,20,40,60,80])
cbar5 = fig.colorbar(t5,ticks=[0,14,28,42,56])
cbar6 = fig.colorbar(t6,ticks=[0,14,28,42,56])
cbar7 = fig.colorbar(t7,ticks=[0,20,40,60,80])
cbar8 = fig.colorbar(t8,ticks=[0,14,28,42,56])
cbar9 = fig.colorbar(t9,ticks=[0,14,28,42,56])


cbar1.set_label(label=r"$G$ (kJ/mol)")
cbar2.set_label(label=r"$G$ (kJ/mol)")
cbar3.set_label(label=r"$G$ (kJ/mol)")
cbar4.set_label(label=r"$G$ (kJ/mol)")
cbar5.set_label(label=r"$G$ (kJ/mol)")
cbar6.set_label(label=r"$G$ (kJ/mol)")
cbar7.set_label(label=r"$G$ (kJ/mol)")
cbar8.set_label(label=r"$G$ (kJ/mol)")
cbar9.set_label(label=r"$G$ (kJ/mol)")

plt.savefig("../L4_tetraloop_project/FES_Ca_Mg.pdf",format="pdf",bbox_inches='tight',dpi=800)
plt.show()
# Out:
# min:-87.250178142 at i=(array([6980]),)
# (6646,)
# (6646,)
# (6646,)
# min:-88.496001847 at i2=(array([7168]),)
# min:-87.284904705 at i3=(array([7180]),)
# min:-105.573922711 at i4=(array([9923]),)
# min:-117.647503304 at i5=(array([7876]),)
# (6646,)
# (6646,)
# (6646,)
# min:-121.875088436 at i6=(array([7823]),)
# min:-125.816163206 at i7=(array([4570]),)
# min:-127.613868508 at i8=(array([9344]),)
# min:-127.339185888 at i9=(array([9370]),)

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, glob
#f=glob.glob("*")[0]
#df=pd.read_csv(f,sep='\s+',comment="#")
df=pd.read_csv("../CN_eRMSD/fes.dat",sep='\s+',comment="#")

eRMSD,d,G=df.iloc[:,0],df.iloc[:,1],df.iloc[:,2]
fig=plt.figure(figsize=(20,12))
#th=input("Enter the value of Gth\n")
th=-30
cscheme="nipy_spectral"
# gmax=input("Enter the maximum value of G\n")
gmax=58
i=np.where(G<=th)
j=np.where(G==np.min(G))
m=G[j[0][0]]
print(f"min:{m} at i={j}")
G=G[i[0]] - m
d=d[i[0]]
gmin=min(G)
gmax=int(gmax)#max(G)/2
eRMSD=eRMSD[i[0]]
#z=np.cos(eRMSD*eRMSD)*np.cos(d*eRMSD)
plt.tricontourf(eRMSD,d,G,levels=50,cmap=cscheme,vmax=gmax,vmin=gmin)
# inf=input("Enter the figure name\n")
#plt.colorbar(label="G (kJ/mol)")
#plt.tick_params(labelsize=16)
cbar = plt.colorbar(label="G (kJ/mol)",ticks=[0,12,24,36,48])
cbar.set_label(label=r"$G$ (kJ/mol)", fontsize=60)
plt.tick_params(labelsize=53,axis="both",length=20,width=2.5,direction="out")
plt.xticks(np.arange(0, max(eRMSD), 2))
plt.yticks(np.arange(2.0, max(d), 0.5))
plt.xlabel("CN",fontsize=60)
plt.ylabel("eRMSD",fontsize=60)
cbar.ax.tick_params(labelsize=60,axis="both",length=20,width=2.5,direction="out")
cbar.ax.set_yticklabels([0,12,24,36,48])
plt.rcParams['axes.linewidth'] = 4
#plt.tick_params(labelsize=30)
#plt.xlabel("CN",fontsize=38)
#plt.ylabel("distance (nm)",fontsize=38)
plt.ylim([2.0,3.8])
# plt.xlim([,1.5])
plt.savefig("../CN_eRMSD/FES_CN_eRMSD_2.5ns_Ca.pdf",format="pdf",bbox_inches='tight',dpi=1200)
plt.show()

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
df=pd.read_csv("../d_eRMSD/fes.dat",sep='\s+',comment="#")

eRMSD,d,G=df.iloc[:,0],df.iloc[:,1],df.iloc[:,2]
fig=plt.figure(figsize=(20,12))
#th=input("Enter the value of Gth\n")
th=-30
#cscheme=input("Enter the color scheme\n")
cscheme="nipy_spectral"
gmax=58
i=np.where(G<=th)
j=np.where(G==np.min(G))
m=G[j[0][0]]
print(f"min:{m} at i={j}")
G=G[i[0]] - m
d=d[i[0]]
gmin=min(G)
gmax=int(gmax)#max(G)/2
eRMSD=eRMSD[i[0]]
plt.tricontourf(eRMSD,d,G,levels=50,cmap=cscheme,vmax=gmax,vmin=gmin)
# inf=input("Enter the figure name\n")
cbar = plt.colorbar(label="G (kJ/mol)",ticks=[0,12,24,36,48])
cbar.set_label(label=r"$G$ (kJ/mol)", fontsize=60)
plt.tick_params(labelsize=53,axis="both",length=20,width=2.5,direction="out")
# plt.rcParams["axes.edgecolor"] = "black"
plt.xticks(np.arange(0.2, max(eRMSD), 0.1))
plt.xlabel("d (nm)",fontsize=60)
plt.ylabel("eRMSD",fontsize=60)
cbar.ax.tick_params(labelsize=60,axis="both",length=20,width=2.5,direction="out")
plt.rcParams['axes.linewidth'] = 2
cbar.ax.set_yticklabels([0,12,24,36,48])
plt.ylim([2.0,3.8])
plt.xlim([0.2,0.8])
plt.savefig("../d_eRMSD/FES_d_eRMSD_2.5ns_Ca.pdf",format="pdf",bbox_inches='tight',dpi=1200)
plt.show()

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, glob
#f=glob.glob("*")[0]
#df=pd.read_csv(f,sep='\s+',comment="#")
df=pd.read_csv("../../Mg_l4_tetraloop_low_K_conc/fold_2_unfold/CN_d/fes.dat",sep='\s+',comment="#")
fig=plt.figure(figsize=(20,12))
eRMSD,d,G=df.iloc[:,0],df.iloc[:,1],df.iloc[:,2]

#th=input("Enter the value of Gth\n")
#th=float(th)
th=-20
#cscheme=input("Enter the color scheme\n")
cscheme="nipy_spectral"
# gmax=input("Enter the maximum value of G\n")
gmax=85
i=np.where(G<=th)
j=np.where(G==np.min(G))
m=G[j[0][0]]
print(f"min:{m} at i={j}")
G=G[i[0]] - m
d=d[i[0]]
gmin=min(G)
gmax=int(gmax)#max(G)/2
eRMSD=eRMSD[i[0]]
#z=np.cos(eRMSD*eRMSD)*np.cos(d*eRMSD)
plt.tricontourf(eRMSD,d,G,levels=50,cmap=cscheme,vmax=gmax,vmin=gmin)
#inf=input("Enter the figure name\n")
#plt.colorbar(label="G (kJ/mol)")
#plt.tick_params(labelsize=16)
cbar = plt.colorbar(label="G (kJ/mol)",ticks=[0,20,40,60,80])
cbar.set_label(label=r"$G$ (kJ/mol)", fontsize=60)
plt.tick_params(labelsize=53)
plt.tick_params(axis="both",length=20,width=2.5,direction="out")
#plt.grid(linestyle="--")
plt.xticks(np.arange(0.18, max(eRMSD), 0.1))
plt.xlabel("d (nm)",fontsize=60)
plt.ylabel("CN",fontsize=60)
cbar.ax.tick_params(labelsize=60,axis="both",length=20,width=2.5,direction="out")
# cbar.ax.set_ticks(np.arange(0,60,12))
cbar.ax.set_yticklabels([0,20,40,60,80])
plt.rcParams['axes.linewidth'] = 2
#plt.tick_params(labelsize=30)
#plt.xlabel("CN",fontsize=38)
#plt.ylabel("distance (nm)",fontsize=38)
plt.ylim([3,12])
plt.xlim([0.18,0.5])
plt.savefig("../../Mg_l4_tetraloop_low_K_conc/fold_2_unfold/CN_d/FES_CN_d_3.4ns_Mg.pdf",format="pdf",bbox_inches='tight',dpi=800)
plt.show()

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, glob
#f=glob.glob("*")[0]
#df=pd.read_csv(f,sep='\s+',comment="#")
df=pd.read_csv("../../Mg_l4_tetraloop_low_K_conc/fold_2_unfold/CN_eRMSD/fes.dat",sep='\s+',comment="#")

eRMSD,d,G=df.iloc[:,0],df.iloc[:,1],df.iloc[:,2]
fig=plt.figure(figsize=(20,12))
#th=input("Enter the value of Gth\n")
th=-30
cscheme="nipy_spectral"
# gmax=input("Enter the maximum value of G\n")
gmax=87
i=np.where(G<=th)
j=np.where(G==np.min(G))
m=G[j[0][0]]
print(f"min:{m} at i={j}")
G=G[i[0]] - m
d=d[i[0]]
gmin=min(G)
gmax=int(gmax)#max(G)/2
eRMSD=eRMSD[i[0]]
#z=np.cos(eRMSD*eRMSD)*np.cos(d*eRMSD)
plt.tricontourf(eRMSD,d,G,levels=50,cmap=cscheme,vmax=gmax,vmin=gmin)
# inf=input("Enter the figure name\n")
#plt.colorbar(label="G (kJ/mol)")
#plt.tick_params(labelsize=16)
cbar = plt.colorbar(label="G (kJ/mol)",ticks=[0,20,40,60,80])
cbar.set_label(label=r"$G$ (kJ/mol)", fontsize=60)
plt.tick_params(labelsize=53,axis="both",length=20,width=2.5,direction="out")
plt.xticks(np.arange(0, max(eRMSD), 2))
plt.yticks(np.arange(2.0, max(d), 0.5))
plt.xlabel("CN",fontsize=60)
plt.ylabel("eRMSD",fontsize=60)
cbar.ax.tick_params(labelsize=60,axis="both",length=20,width=2.5,direction="out")
cbar.ax.set_yticklabels([0,20,40,60,80])
plt.rcParams['axes.linewidth'] = 3
#plt.tick_params(labelsize=30)
#plt.xlabel("CN",fontsize=38)
#plt.ylabel("distance (nm)",fontsize=38)
plt.ylim([2.0,3.7])
plt.xlim([4,12])
plt.savefig("../../Mg_l4_tetraloop_low_K_conc/fold_2_unfold/CN_eRMSD/FES_CN_eRMSD_2.5ns_Mg.pdf",format="pdf",bbox_inches='tight',dpi=1200)
plt.show()

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
df=pd.read_csv("../../Mg_l4_tetraloop_low_K_conc/fold_2_unfold/d_eRMSD/fes.dat",sep='\s+',comment="#")

eRMSD,d,G=df.iloc[:,0],df.iloc[:,1],df.iloc[:,2]
fig=plt.figure(figsize=(20,12))
#th=input("Enter the value of Gth\n")
th=-30
#cscheme=input("Enter the color scheme\n")
cscheme="nipy_spectral"
gmax=91
i=np.where(G<=th)
j=np.where(G==np.min(G))
m=G[j[0][0]]
print(f"min:{m} at i={j}")
G=G[i[0]] - m
d=d[i[0]]
gmin=min(G)
gmax=int(gmax)#max(G)/2
eRMSD=eRMSD[i[0]]
plt.tricontourf(eRMSD,d,G,levels=50,cmap=cscheme,vmax=gmax,vmin=gmin)
# inf=input("Enter the figure name\n")
cbar = plt.colorbar(label="G (kJ/mol)",ticks=[0,20,40,60,80])
cbar.set_label(label=r"$G$ (kJ/mol)", fontsize=60)
plt.tick_params(labelsize=53,axis="both",length=20,width=2.5,direction="out")
# plt.rcParams["axes.edgecolor"] = "black"
plt.xticks(np.arange(0.2, max(eRMSD), 0.1))
plt.xlabel("d (nm)",fontsize=60)
plt.ylabel("eRMSD",fontsize=60)
cbar.ax.tick_params(labelsize=60,axis="both",length=20,width=2.5,direction="out")
plt.rcParams['axes.linewidth'] = 4
cbar.ax.set_yticklabels([0,20,40,60,80])
plt.ylim([1.0,3.7])
plt.xlim([0.18,0.6])
plt.savefig("../../Mg_l4_tetraloop_low_K_conc/fold_2_unfold/d_eRMSD/FES_d_eRMSD_2.5ns_Mg.pdf",format="pdf",bbox_inches='tight',dpi=1200)
plt.show()

# %%
import pandas as pd, matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
mpl.rcParams['agg.path.chunksize'] = 10000

df=pd.read_csv('../../Mg_l4_tetraloop_low_K_conc/fold_2_unfold/a.dat', sep='\s+', header=None).dropna()
t,e,c,d,h=df.iloc[:,0]/1000, df.iloc[:,2], df.iloc[:,3], df.iloc[:,4],  df.iloc[:,8]
fig, ax = plt.subplots(3,figsize=(10, 10))
#ax1 = ax.twinx()
#ax2 = ax.twinx()

ax[0].plot(t,e,color = 'r')
plt.suptitle("Mg$^{2+}$", fontsize=38,color='purple')
ax[1].plot(t,c,color = 'g')
ax[2].plot(t,d,color = 'b')


ax[0].set_ylabel("eRMSD",fontsize=33)
ax[1].set_ylabel('CN',fontsize=33)
ax[2].set_ylabel('d (nm)',fontsize=33)
ax[2].set_xlabel('time (ns)',fontsize=33)

#ax[2].set_xticks(np.arange(0, max(t), 1000))
ax[0].set_yticks(np.arange(0, max(e), 1.0))
ax[1].set_yticks(np.arange(0, max(c), 4.0))
ax[2].set_yticks(np.arange(0, max(d), 0.2))
"""
ax[0].set_ylim([0.0,4.0)]
ax[1].set_ylabel('CN',fontsize=20)
ax[2].set_ylabel('d (nm)',fontsize=20)
ax[2].set_xlabel('time (ns)',fontsize=20)
"""
ax[0].tick_params(labelsize=30,axis="both",length=8,width=2.5,direction="inout")
ax[1].tick_params(labelsize=30,axis="both",length=8,width=2.5,direction="inout")
ax[2].tick_params(labelsize=30,axis="both",length=8,width=2.5,direction="inout")

#plt.legend()

plt.savefig('../../Mg_l4_tetraloop_low_K_conc/fold_2_unfold/hill_plot_Mg2+.pdf',format="pdf",dpi=800, bbox_inches='tight')
plt.show()

# %%
import pandas as pd, matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
mpl.rcParams['agg.path.chunksize'] = 10000

df=pd.read_csv('../../Ca_l4_tetraloop_low_K_conc/a.dat', sep='\s+', header=None).dropna()
t,e,c,d,h=df.iloc[:,0]/1000, df.iloc[:,2], df.iloc[:,3], df.iloc[:,4],  df.iloc[:,8]
fig, ax = plt.subplots(3,figsize=(10, 10))
#ax1 = ax.twinx()
#ax2 = ax.twinx()

ax[0].plot(t,e,color = 'r')
plt.suptitle("Ca$^{2+}$", fontsize=38,color='purple' )
ax[1].plot(t,c,color = 'g')
ax[2].plot(t,d,color = 'b')


ax[0].set_ylabel("eRMSD",fontsize=33)
ax[1].set_ylabel('CN',fontsize=33)
ax[2].set_ylabel('d (nm)',fontsize=33)
ax[2].set_xlabel('time (ns)',fontsize=33)

ax[2].set_xticks(np.arange(0, max(t), 500))
ax[0].set_yticks(np.arange(0, max(e), 1.0))
ax[1].set_yticks(np.arange(0, max(c), 4.0))
ax[2].set_yticks(np.arange(0.1, max(d), 0.2))
"""
ax[0].set_ylim([0.0,4.0)]
ax[1].set_ylabel('CN',fontsize=20)
ax[2].set_ylabel('d (nm)',fontsize=20)
ax[2].set_xlabel('time (ns)',fontsize=20)
"""
ax[0].tick_params(labelsize=30,axis="both",length=8,width=2.5,direction="inout")
ax[1].tick_params(labelsize=30,axis="both",length=8,width=2.5,direction="inout")
ax[2].tick_params(labelsize=30,axis="both",length=8,width=2.5,direction="inout")

#plt.legend()

plt.savefig('../../Ca_l4_tetraloop_low_K_conc/hill_plot_Ca2+.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, glob

file=glob.glob('../../ff*')
df1=pd.read_csv(file[0],sep='\s+',engine='python',comment='#') #dock
df2=pd.read_csv(file[1],sep='\s+',engine='python',comment='#') #undock
fig=plt.figure(figsize=(20,12))
eRMSD1,G1=df1.iloc[:,0],df1.iloc[:,1]
eRMSD2,G2=df2.iloc[:,0],df2.iloc[:,1]
m1=np.min(G1)
m2=np.min(G2)

m=min(m1,m2)
G1=G1-m
G2=G2-m
pt=input("Enter the shift value\n")
p=float(pt)

plt.plot(eRMSD1,G1+p,label="Ca$^{2+}$",linewidth='6',color='r')
plt.plot(eRMSD2,G2,label="Mg$^{2+}$",linewidth='6',color='b')
plt.xlabel('CN$_{M^{2+}}^{ON}$', fontsize=55)
plt.ylabel('G (kJ/mol)',fontsize=55)
plt.xticks(np.arange(0, 7, 1))
plt.ylim([0,65])
plt.xlim([0,6])
plt.tick_params(labelsize=53,axis="both",length=20,width=2.5,direction="out")
plt.legend(fontsize=55)
plt.savefig('../../CN_oxygen_vs_G.pdf', format="pdf", bbox_inches='tight',dpi=600)
plt.show()

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt



df = pd.read_csv('../../Ca_l4_tetraloop_low_K_conc/oxygen_count_2.7ang_around_Ca_0-1655ns.dat',sep="\s", skiprows=1,engine='python')
fig = plt.figure(figsize=(20,12))
plt.suptitle("Ca$^{2+}$", fontsize=60)


x,y,z=df.iloc[:,0]/1000,df.iloc[:,1],df.iloc[:,2]


#label_name=input("enter the legend to be written\n")
plt.plot(x,z,linewidth='4',color="blue")
plt.xlabel("time (ns)",fontsize=55)
plt.ylabel("CN$_{Ca^{2+}}^{H_2O}$",fontsize=55)
plt.tick_params(labelsize=53,axis="both",length=20,width=2.5,direction="out")
plt.xticks(np.arange(0, max(x), 500))
plt.yticks(np.arange(1, 9.2, 2))
plt.rcParams['axes.linewidth'] = 5
plt.ylim([0,6])
#plt.legend()
plt.savefig("../../Ca_l4_tetraloop_low_K_conc/water_around_Ca.png",dpi=600,bbox_inches="tight")
plt.show()
print("your file is saved, check in the folder of the script\n")

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt



df = pd.read_csv('../../Mg_l4_tetraloop_low_K_conc/fold_2_unfold/p_oxygen_count_around_MG_0-2956ns.dat',sep="\s", skiprows=1,engine='python')
fig = plt.figure(figsize=(20,12))
plt.suptitle("Mg$^{2+}$", fontsize=60)


x,y,z=df.iloc[:,0]/1000,df.iloc[:,1],df.iloc[:,2]


#label_name=input("enter the legend to be written\n")
plt.plot(x,z,linewidth='4',color="blue")
plt.xlabel("time (ns)",fontsize=55)
plt.ylabel("CN$_{Mg^{2+}}^{H_2O}$",fontsize=55)
plt.tick_params(labelsize=53,axis="both",length=20,width=2.5,direction="out")
plt.xticks(np.arange(0, max(x), 800))
plt.yticks(np.arange(2, 6.2, 1))
#plt.ylim([0,6.2])
#plt.legend()
plt.savefig("../../Mg_l4_tetraloop_low_K_conc/fold_2_unfold/water_around_Mg.pdf",format="pdf",dpi=800,bbox_inches="tight")
plt.show()
print("your file is saved, check in the folder of the script\n")

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, glob
f=glob.glob("../../Mg_l4_tetraloop_low_K_conc/fold_2_unfold/ff_cn_2.7ang_eRMSD.dat")[0]
df=pd.read_csv(f,sep='\s+',comment="#")

eRMSD,d,G=df.iloc[:,0],df.iloc[:,1],df.iloc[:,2]

# th=input("Enter the value of Gth\n")
# th=float(th)
th=0
i=np.where(G<=th)
j=np.where(G==np.min(G))
m=G[j[0][0]]
print(f"min:{m} at i={j}")
G=G[i[0]] - m
d=d[i[0]]
eRMSD=eRMSD[i[0]]
plt.tricontourf(eRMSD,d,G,levels=50,cmap='jet')
plt.colorbar(label="G (kJ/mol)")
plt.tick_params(labelsize=16)
plt.xlabel("eRMSD",fontsize=24)
plt.ylabel("CN",fontsize=24)
plt.rcParams['axes.linewidth'] = 1
plt.savefig("../../Mg_l4_tetraloop_low_K_conc/fold_2_unfold/FES_cutoffCN_2.7ang.pdf",format="pdf",bbox_inches='tight',dpi=1200)

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, glob
f=glob.glob("../L4_tetraloop_project/Ca_l4_tetraloop_low_K_conc/ff.dat")[0]
df=pd.read_csv(f,sep='\s+',comment="#")

eRMSD,d,G=df.iloc[:,0],df.iloc[:,1],df.iloc[:,2]

# th=input("Enter the value of Gth\n")
# th=float(th)
th=-10
i=np.where(G<=th)
j=np.where(G==np.min(G))
m=G[j[0][0]]
print(f"min:{m} at i={j}")
G=G[i[0]] - m
d=d[i[0]]
eRMSD=eRMSD[i[0]]
plt.tricontourf(eRMSD,d,G,levels=50,cmap='jet')
plt.colorbar(label="G (kJ/mol)")
plt.tick_params(labelsize=16)
plt.xlabel("eRMSD",fontsize=24)
plt.ylabel("CN",fontsize=24)
plt.rcParams['axes.linewidth'] = 1
plt.savefig("../L4_tetraloop_project/Ca_l4_tetraloop_low_K_conc/FES_cutoffCN_2.7ang_Ca.pdf",format="pdf",bbox_inches='tight',dpi=1200)

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, glob
f=glob.glob("../../Mn_l4_tetraloop_low_K_conc/ff_eRMSD_CN-0.27.dat")[0]
df=pd.read_csv(f,sep='\s+',comment="#")

eRMSD,d,G=df.iloc[:,0],df.iloc[:,1],df.iloc[:,2]

# th=input("Enter the value of Gth\n")
# th=float(th)
th=0
i=np.where(G<=th)
j=np.where(G==np.min(G))
m=G[j[0][0]]
print(f"min:{m} at i={j}")
G=G[i[0]] - m
d=d[i[0]]
eRMSD=eRMSD[i[0]]
plt.tricontourf(eRMSD,d,G,levels=50,cmap='jet')
plt.colorbar(label="G (kJ/mol)")
plt.tick_params(labelsize=16)
plt.xlabel("eRMSD",fontsize=24)
plt.ylabel("CN",fontsize=24)
plt.rcParams['axes.linewidth'] = 1
plt.savefig("../../Mn_l4_tetraloop_low_K_conc/FES_cutoffCN_2.7ang_Mn.pdf",format="pdf",bbox_inches='tight',dpi=1200)

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
df=pd.read_csv("../../Mn_l4_tetraloop_low_K_conc/CN_d/fes.dat",sep='\s+',comment="#")

eRMSD,d,G=df.iloc[:,0],df.iloc[:,1],df.iloc[:,2]
fig=plt.figure(figsize=(20,12))
#th=input("Enter the value of Gth\n")
th=-30
#cscheme=input("Enter the color scheme\n")
cscheme="nipy_spectral"
gmax=95
i=np.where(G<=th)
j=np.where(G==np.min(G))
m=G[j[0][0]]
print(f"min:{m} at i={j}")
G=G[i[0]] - m
d=d[i[0]]
gmin=min(G)
gmax=int(gmax)#max(G)/2
eRMSD=eRMSD[i[0]]
plt.tricontourf(eRMSD,d,G,levels=50,cmap=cscheme,vmax=gmax,vmin=gmin)
# inf=input("Enter the figure name\n")
cbar = plt.colorbar(label="G (kJ/mol)",ticks=[0,25,50,70,90])
cbar.set_label(label=r"$G$ (kJ/mol)", fontsize=60)
plt.tick_params(labelsize=53,axis="both",length=20,width=2.5,direction="out")
# plt.rcParams["axes.edgecolor"] = "black"
plt.xticks(np.arange(0.2, max(eRMSD), 0.1))
plt.xlabel("d (nm)",fontsize=60)
plt.ylabel("CN",fontsize=60)
cbar.ax.tick_params(labelsize=60,axis="both",length=20,width=2.5,direction="out")
plt.rcParams['axes.linewidth'] = 2
cbar.ax.set_yticklabels([0,25,50,70,90])
plt.ylim([3,8])
plt.xlim([0.18,0.5])
plt.savefig("../../Mn_l4_tetraloop_low_K_conc/CN_d/FES_CN_d_2.8us_Mn.pdf",format="pdf",bbox_inches='tight',dpi=1200)
plt.show()

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
df=pd.read_csv("../../Mn_l4_tetraloop_low_K_conc/CN_eRMSD/fes.dat",sep='\s+',comment="#")

eRMSD,d,G=df.iloc[:,0],df.iloc[:,1],df.iloc[:,2]
fig=plt.figure(figsize=(20,12))
#th=input("Enter the value of Gth\n")
th=-30
#cscheme=input("Enter the color scheme\n")
cscheme="nipy_spectral"
gmax=95
i=np.where(G<=th)
j=np.where(G==np.min(G))
m=G[j[0][0]]
print(f"min:{m} at i={j}")
G=G[i[0]] - m
d=d[i[0]]
gmin=min(G)
gmax=int(gmax)#max(G)/2
eRMSD=eRMSD[i[0]]
plt.tricontourf(eRMSD,d,G,levels=50,cmap=cscheme,vmax=gmax,vmin=gmin)
# inf=input("Enter the figure name\n")
cbar = plt.colorbar(label="G (kJ/mol)",ticks=[0,25,50,70,90])
cbar.set_label(label=r"$G$ (kJ/mol)", fontsize=60)
plt.tick_params(labelsize=53,axis="both",length=20,width=2.5,direction="out")
# plt.rcParams["axes.edgecolor"] = "black"
# plt.xticks(np.arange(0.2, max(eRMSD), 0.1))
plt.xlabel("CN",fontsize=60)
plt.ylabel("eRMSD",fontsize=60)
cbar.ax.tick_params(labelsize=60,axis="both",length=20,width=2.5,direction="out")
plt.rcParams['axes.linewidth'] = 2
cbar.ax.set_yticklabels([0,25,50,70,90])
plt.ylim([2.0,3.8])
plt.xlim([1,8])
plt.savefig("../../Mn_l4_tetraloop_low_K_conc/CN_eRMSD/FES_CN_eRMSD_2.8us_Mn.pdf",format="pdf",bbox_inches='tight',dpi=1200)
plt.show()

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
df=pd.read_csv("../../Mn_l4_tetraloop_low_K_conc/d_eRMSD/fes.dat",sep='\s+',comment="#")

eRMSD,d,G=df.iloc[:,0],df.iloc[:,1],df.iloc[:,2]
fig=plt.figure(figsize=(20,12))
#th=input("Enter the value of Gth\n")
th=-30
#cscheme=input("Enter the color scheme\n")
cscheme="nipy_spectral"
gmax=95
i=np.where(G<=th)
j=np.where(G==np.min(G))
m=G[j[0][0]]
print(f"min:{m} at i={j}")
G=G[i[0]] - m
d=d[i[0]]
gmin=min(G)
gmax=int(gmax)#max(G)/2
eRMSD=eRMSD[i[0]]
plt.tricontourf(eRMSD,d,G,levels=50,cmap=cscheme,vmax=gmax,vmin=gmin)
# inf=input("Enter the figure name\n")
cbar = plt.colorbar(label="G (kJ/mol)",ticks=[0,25,50,70,90])
cbar.set_label(label=r"$G$ (kJ/mol)", fontsize=60)
plt.tick_params(labelsize=53,axis="both",length=20,width=2.5,direction="out")
# plt.rcParams["axes.edgecolor"] = "black"
# plt.xticks(np.arange(0.2, max(eRMSD), 0.1))
plt.xlabel("distance (nm)",fontsize=60)
plt.ylabel("eRMSD",fontsize=60)
cbar.ax.tick_params(labelsize=60,axis="both",length=20,width=2.5,direction="out")
plt.rcParams['axes.linewidth'] = 2
cbar.ax.set_yticklabels([0,25,50,70,90])
plt.ylim([2.0,3.8])
plt.xlim([0.18,0.5])
plt.savefig("../../Mn_l4_tetraloop_low_K_conc/d_eRMSD/FES_d_eRMSD_2.8us_Mn.pdf",format="pdf",bbox_inches='tight',dpi=1200)
plt.show()

# %%
import pandas as pd, matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
mpl.rcParams['agg.path.chunksize'] = 10000

df=pd.read_csv('../../Mg_l4_tetraloop_low_K_conc/fold_2_unfold/a.dat', sep='\s+', header=None).dropna()
t,e,c,d,h=df.iloc[:,0]/1000, df.iloc[:,2], df.iloc[:,3], df.iloc[:,4],  df.iloc[:,8]
fig, ax = plt.subplots(3,figsize=(10, 10))
#ax1 = ax.twinx()
#ax2 = ax.twinx()

ax[0].plot(t,e,color = 'r')
plt.suptitle("Mg$^{2+}$", fontsize=38)
ax[1].plot(t,c,color = 'g')
ax[2].plot(t,d,color = 'b')


ax[0].set_ylabel("eRMSD",fontsize=33)
ax[1].set_ylabel('CN',fontsize=33)
ax[2].set_ylabel('d (nm)',fontsize=33)
ax[2].set_xlabel('time (ns)',fontsize=33)

#ax[2].set_xticks(np.arange(0, max(t), 1000))
ax[0].set_yticks(np.arange(0, max(e), 1.0))
ax[1].set_yticks(np.arange(0, max(c), 4.0))
ax[2].set_yticks(np.arange(0, max(d), 0.2))
"""
ax[0].set_ylim([0.0,4.0)]
ax[1].set_ylabel('CN',fontsize=20)
ax[2].set_ylabel('d (nm)',fontsize=20)
ax[2].set_xlabel('time (ns)',fontsize=20)
"""
ax[0].tick_params(labelsize=30)
ax[1].tick_params(labelsize=30)
ax[2].tick_params(labelsize=30)

#plt.legend()

plt.savefig('../../Mg_l4_tetraloop_low_K_conc/fold_2_unfold/hill_plot_Mg2+.pdf', format="pdf", dpi=600, bbox_inches='tight')
plt.show()

# %%
import pandas as pd, matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
mpl.rcParams['agg.path.chunksize'] = 10000

df=pd.read_csv('../../Ca_l4_tetraloop_low_K_conc/a.dat', sep='\s+', header=None).dropna()
t,e,c,d,h=df.iloc[:,0]/1000, df.iloc[:,2], df.iloc[:,3], df.iloc[:,4],  df.iloc[:,8]
fig, ax = plt.subplots(3,figsize=(10, 10))
#ax1 = ax.twinx()
#ax2 = ax.twinx()

ax[0].plot(t,e,color = 'r')
plt.suptitle("Ca$^{2+}$", fontsize=38)
ax[1].plot(t,c,color = 'g')
ax[2].plot(t,d,color = 'b')


ax[0].set_ylabel("eRMSD",fontsize=33)
ax[1].set_ylabel('CN',fontsize=33)
ax[2].set_ylabel('d (nm)',fontsize=33)
ax[2].set_xlabel('time (ns)',fontsize=33)

#ax[2].set_xticks(np.arange(0, max(t), 1000))
ax[0].set_yticks(np.arange(0, max(e), 1.0))
ax[1].set_yticks(np.arange(0, max(c), 4.0))
ax[2].set_yticks(np.arange(0, max(d), 0.2))
"""
ax[0].set_ylim([0.0,4.0)]
ax[1].set_ylabel('CN',fontsize=20)
ax[2].set_ylabel('d (nm)',fontsize=20)
ax[2].set_xlabel('time (ns)',fontsize=20)
"""
ax[0].tick_params(labelsize=30)
ax[1].tick_params(labelsize=30)
ax[2].tick_params(labelsize=30)

#plt.legend()

plt.savefig('../../Ca_l4_tetraloop_low_K_conc/hill_plot_Ca2+.pdf', format="pdf", dpi=600, bbox_inches='tight')
plt.show()

# %%
import pandas as pd, matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
mpl.rcParams['agg.path.chunksize'] = 10000

df=pd.read_csv('../../Mn_l4_tetraloop_low_K_conc/a.dat', sep='\s+', header=None).dropna()
t,e,c,d,h=df.iloc[:,0]/1000, df.iloc[:,2], df.iloc[:,3], df.iloc[:,4],  df.iloc[:,8]
fig, ax = plt.subplots(3,figsize=(10, 10))
#ax1 = ax.twinx()
#ax2 = ax.twinx()

ax[0].plot(t,e,color = 'r')
plt.suptitle("Mn$^{2+}$", fontsize=38)
ax[1].plot(t,c,color = 'g')
ax[2].plot(t,d,color = 'b')


ax[0].set_ylabel("eRMSD",fontsize=33)
ax[1].set_ylabel('CN',fontsize=33)
ax[2].set_ylabel('d (nm)',fontsize=33)
ax[2].set_xlabel('time (ns)',fontsize=33)

#ax[2].set_xticks(np.arange(0, max(t), 1000))
ax[0].set_yticks(np.arange(0, max(e), 1.0))
ax[1].set_yticks(np.arange(0, max(c), 4.0))
ax[2].set_yticks(np.arange(0, max(d), 0.2))
"""
ax[0].set_ylim([0.0,4.0)]
ax[1].set_ylabel('CN',fontsize=20)
ax[2].set_ylabel('d (nm)',fontsize=20)
ax[2].set_xlabel('time (ns)',fontsize=20)
"""
ax[0].tick_params(labelsize=30)
ax[1].tick_params(labelsize=30)
ax[2].tick_params(labelsize=30)

#plt.legend()

plt.savefig('../../Mn_l4_tetraloop_low_K_conc/hill_plot_Mn2+.pdf', format="pdf", dpi=600, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from colors import colors
from matplotlib.path import Path
import matplotlib.patches as patches

df=pd.read_csv("../data_analysis_GAAA_project/new_cv_d1_cmap/fes.dat",sep='\s+',comment="#")

eRMSD,d,G=df.iloc[:,0],df.iloc[:,1],df.iloc[:,2]
fig=plt.figure(figsize=(6,4))
# fig, ax = plt.subplots(1,1,figsize=(6,4), dpi=800,constrained_layout=True)
#th=input("Enter the value of Gth\n")
th=0
cscheme="nipy_spectral"
# gmax=input("Enter the maximum value of G\n")
gmax=135
i=np.where(G<=th)
j=np.where(G==np.min(G))
m=G[j[0][0]]
print(f"min:{m} at i={j}")
G=G[i[0]] - m
d=d[i[0]]
gmax=m
print(gmax)
# gmax=int(m)
gmin=min(G)
gmin=int(gmin)
# print(gmin)
gmax=int(gmax)#max(G)/2
eRMSD=eRMSD[i[0]]

plt.tricontourf(eRMSD,d,G,levels=50,cmap=cscheme,vmin=gmin,vmax=gmax)

mpl.rc('figure')

mpl.rcParams['text.usetex'] = True
mpl.rcParams[
    'text.latex.preamble'] = r'\usepackage[cm]{sfmath}\usepackage{amsmath}\usepackage{amssymb}'

mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = 'CMU Sans Serif'

font_size = 20

fonts = {
    "axes.labelsize": font_size,
    "font.size": font_size,
    "legend.fontsize": font_size,
    "xtick.labelsize": font_size,
    "ytick.labelsize": font_size,
    "axes.titlesize": font_size,
}

mpl.rcParams.update(fonts)

axes_settings = {
    "axes.labelcolor": '#2e2e2e',
    "axes.spines.top": True,
    "axes.spines.right": True,
    "xtick.direction": "out",
    "ytick.direction": "out",
    "xtick.color": '#2e2e2e',
    "ytick.color": '#2e2e2e',
    "text.color": '#2e2e2e',
    "axes.edgecolor": '#2e2e2e',
}
mpl.rcParams.update(axes_settings)

cbar = plt.colorbar(label="G (kJ/mol)",ticks=[0,30,60,90,120])
cbar.set_label(label=r"$G$ (kJ/mol)")

plt.xlabel("d")
plt.ylabel("cmap")

plt.savefig("../data_analysis_GAAA_project/new_cv_d1_cmap/FES_d_cmap_upto-650ns.pdf",format="pdf",bbox_inches='tight',dpi=1200)
plt.show()

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, glob
#f=glob.glob("*")[0]
#df=pd.read_csv(f,sep='\s+',comment="#")
df=pd.read_csv("../data_analysis_GAAA_project/TUE_data_25_oct_2022/hiranmay_TUE/new_run_4_copy_with_new_plumed_input/ff_2d_dcm_cmap.dat",sep='\s+',comment="#")

eRMSD,d,G=df.iloc[:,0],df.iloc[:,1],df.iloc[:,2]
fig=plt.figure(figsize=(20,12))
#th=input("Enter the value of Gth\n")
th=-50
cscheme="nipy_spectral"
# gmax=input("Enter the maximum value of G\n")
gmax=85
i=np.where(G<=th)
j=np.where(G==np.min(G))
m=G[j[0][0]]
print(f"min:{m} at i={j}")
G=G[i[0]] - m
d=d[i[0]]
gmin=min(G)
gmax=int(gmax)#max(G)/2
eRMSD=eRMSD[i[0]]
#z=np.cos(eRMSD*eRMSD)*np.cos(d*eRMSD)
plt.tricontourf(eRMSD,d,G,levels=50,cmap=cscheme,vmax=gmax,vmin=gmin)
# inf=input("Enter the figure name\n")
#plt.colorbar(label="G (kJ/mol)")
#plt.tick_params(labelsize=16)
# cbar = plt.colorbar(label="G (kJ/mol)",ticks=[0,12,24,36,48])
cbar = plt.colorbar(label="G (kJ/mol)")
cbar.set_label(label=r"$G$ (kJ/mol)", fontsize=60)
plt.tick_params(labelsize=53,axis="both",length=20,width=2.5,direction="out")
# plt.xticks(np.arange(0, max(eRMSD), 2))
# plt.yticks(np.arange(2.0, max(d), 0.5))
plt.xlabel("d",fontsize=60)
plt.ylabel("cmap",fontsize=60)
cbar.ax.tick_params(labelsize=60,axis="both",length=20,width=2.5,direction="out")
# cbar.ax.set_yticklabels([0,12,24,36,48])
plt.rcParams['axes.linewidth'] = 4
#plt.tick_params(labelsize=30)
#plt.xlabel("CN",fontsize=38)
#plt.ylabel("distance (nm)",fontsize=38)
# plt.ylim([2.0,3.8])
# plt.xlim([,1.5])
plt.savefig("../data_analysis_GAAA_project/new_cv_d1_cmap/FES_d_cmap_upto-650ns.pdf",format="pdf",bbox_inches='tight',dpi=1200)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from colors import colors
from matplotlib.path import Path
import matplotlib.patches as patches
# import matplotlib.mpatches as mpatches
mpl.rc('figure')

mpl.rcParams['text.usetex'] = True
mpl.rcParams[
    'text.latex.preamble'] = r'\usepackage[cm]{sfmath}\usepackage{amsmath}\usepackage{amssymb}'

mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = 'CMU Sans Serif'

font_size = 10

fonts = {
    "axes.labelsize": font_size,
    "font.size": font_size,
    "legend.fontsize": font_size,
    "xtick.labelsize": font_size,
    "ytick.labelsize": font_size,
    "axes.titlesize": font_size,
}

mpl.rcParams.update(fonts)

axes_settings = {
    "axes.labelcolor": '#202020',
    "axes.spines.top": False,
    "axes.spines.right": False,
    "xtick.direction": "out",
    "ytick.direction": "out",
    "xtick.color": '#202020',
    "ytick.color": '#202020',
    "text.color": '#202020',
    "axes.edgecolor": '#202020',
}
mpl.rcParams.update(axes_settings)

mpl.rcParams['axes.grid'] = True
mpl.rcParams['grid.alpha'] = 0.5
mpl.rcParams['grid.color'] = 'grey'
mpl.rcParams['grid.linestyle'] = ':'
mpl.rcParams['grid.linewidth'] = 0.1


saxs_col = colors['violet'][7]
fret_col = colors['teal'][7]
ratio_col = colors['red'][6]
ebar_color = 'black'
marker_size = 5
color_dict = {'SAXS': saxs_col, 'FRET': fret_col, 'Ratio': ratio_col}
label_dict = {
    'SAXS': r'$\large{\nu_{SAXS}}$',
    'FRET': r'$\large{\nu_{FRET}}$',
    'Ratio': r'$\large{\nu_{\rm Ratio}}$'
}

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
a = [0,1,68,-90,-60,4.3,-6.9,5]

# %%
# i=np.where(G<=th)
a[3]

print (a[3])

# %%
th=0
i=np.where(G<=th)
j=np.where(G==np.min(G))
m=G[j[0][0]]
print(f"min:{m} at i={j}")
G=G[i[0]] - m
d=d[i[0]]
